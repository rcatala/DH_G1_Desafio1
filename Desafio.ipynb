# %%
#Importo pandas y numpy

import numpy as np
import pandas as pd

# %%
#Guardo el path del archivo en una variable para despues cargarlo en un df

file = 'C:/Users/Ramiro/Desktop/Digital House/Desafios/properatti.csv'

# Creo un DataFrame con la info del csv
df = pd.read_csv(file)

# %%
# Veo la forma del df
df.sample(20)
# Out:
#         Unnamed: 0 operation property_type           place_name  \
# 114074      114074      sell         house      Acacias Blancas
# 54132        54132      sell         house                Tigre
# 111726      111726      sell     apartment         Constitución
# 120493      120493      sell         house        Villa Allende
# 42447        42447      sell         house         Villa Lugano
# 98376        98376      sell     apartment              Córdoba
# 19705        19705      sell     apartment        Villa Urquiza
# 56009        56009      sell     apartment   Altos de Hudson II
# 13015        13015      sell     apartment         Palermo Soho
# 1881          1881      sell         house  Carmel Country Club
# 93233        93233      sell     apartment              Córdoba
# 48103        48103      sell            PH        Mar del Plata
# 109178      109178      sell     apartment              Córdoba
# 5758          5758      sell         house        Mar del Plata
# 21696        21696      sell         house                Haedo
# 109294      109294      sell     apartment              Rosario
# 98682        98682      sell     apartment             Belgrano
# 12549        12549      sell            PH     Villa Pueyrredón
# 51              51      sell         house                Boedo
# 54907        54907      sell     apartment        Mar del Plata
#
#                                   place_with_parent_names country_name  \
# 114074  |Argentina|Bs.As. G.B.A. Zona Norte|Escobar|Ac...    Argentina
# 54132          |Argentina|Bs.As. G.B.A. Zona Norte|Tigre|    Argentina
# 111726  |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 120493                  |Argentina|Córdoba|Villa Allende|    Argentina
# 42447            |Argentina|Capital Federal|Villa Lugano|    Argentina
# 98376                                 |Argentina|Córdoba|    Argentina
# 19705           |Argentina|Capital Federal|Villa Urquiza|    Argentina
# 56009   |Argentina|Bs.As. G.B.A. Zona Sur|Berazategui|...    Argentina
# 13015    |Argentina|Capital Federal|Palermo|Palermo Soho|    Argentina
# 1881    |Argentina|Bs.As. G.B.A. Zona Norte|Pilar|Carm...    Argentina
# 93233                                 |Argentina|Córdoba|    Argentina
# 48103   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 109178                        |Argentina|Córdoba|Córdoba|    Argentina
# 5758    |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
# 21696    |Argentina|Bs.As. G.B.A. Zona Oeste|Morón|Haedo|    Argentina
# 109294                       |Argentina|Santa Fe|Rosario|    Argentina
# 98682                |Argentina|Capital Federal|Belgrano|    Argentina
# 12549        |Argentina|Capital Federal|Villa Pueyrredón|    Argentina
# 51                      |Argentina|Capital Federal|Boedo|    Argentina
# 54907   |Argentina|Buenos Aires Costa Atlántica|Mar de...    Argentina
#
#                           state_name  geonames_id  \
# 114074      Bs.As. G.B.A. Zona Norte          NaN
# 54132       Bs.As. G.B.A. Zona Norte    3427753.0
# 111726  Buenos Aires Costa Atlántica          NaN
# 120493                       Córdoba    3832815.0
# 42447                Capital Federal    3427408.0
# 98376                        Córdoba    3860255.0
# 19705                Capital Federal    3433775.0
# 56009         Bs.As. G.B.A. Zona Sur          NaN
# 13015                Capital Federal    3430234.0
# 1881        Bs.As. G.B.A. Zona Norte          NaN
# 93233                        Córdoba    3860255.0
# 48103   Buenos Aires Costa Atlántica    3430863.0
# 109178                       Córdoba    3860259.0
# 5758    Buenos Aires Costa Atlántica    3430863.0
# 21696       Bs.As. G.B.A. Zona Oeste          NaN
# 109294                      Santa Fe    3838574.0
# 98682                Capital Federal    3436077.0
# 12549                Capital Federal    3429703.0
# 51                   Capital Federal    3436003.0
# 54907   Buenos Aires Costa Atlántica    3430863.0
#
#                               lat-lon        lat  \
# 114074                            NaN        NaN
# 54132                             NaN        NaN
# 111726                            NaN        NaN
# 120493                            NaN        NaN
# 42447         -34.6780032,-58.4722813 -34.678003
# 98376                             NaN        NaN
# 19705           -34.573876,-58.483581 -34.573876
# 56009          -34.8065123,-58.171565 -34.806512
# 13015                             NaN        NaN
# 1881         -34.3929863,-58.86713028 -34.392986
# 93233                             NaN        NaN
# 48103         -38.0151568,-57.5738705 -38.015157
# 109178                            NaN        NaN
# 5758           -37.9924981,-57.608127 -37.992498
# 21696                             NaN        NaN
# 109294                            NaN        NaN
# 98682   -34.5695166785,-58.4514690696 -34.569517
# 12549   -34.5789246705,-58.5110764113 -34.578925
# 51            -34.6363209,-58.4107019 -34.636321
# 54907   -37.9917554972,-57.5493590762 -37.991755
#
#                               ...                          \
# 114074                        ...
# 54132                         ...
# 111726                        ...
# 120493                        ...
# 42447                         ...
# 98376                         ...
# 19705                         ...
# 56009                         ...
# 13015                         ...
# 1881                          ...
# 93233                         ...
# 48103                         ...
# 109178                        ...
# 5758                          ...
# 21696                         ...
# 109294                        ...
# 98682                         ...
# 12549                         ...
# 51                            ...
# 54907                         ...
#
#         surface_covered_in_m2  price_usd_per_m2  price_per_m2  floor  rooms  \
# 114074                   90.0               NaN   1877.777778    NaN    NaN
# 54132                   146.0       1767.123288   1767.123288    NaN    NaN
# 111726                  175.0               NaN   1565.600000    NaN    NaN
# 120493                  440.0               NaN           NaN    NaN    NaN
# 42447                   260.0       1134.615385   1134.615385    NaN    NaN
# 98376                    38.0       1461.127368  26052.631579    NaN    NaN
# 19705                   294.0               NaN   3333.333333    NaN    6.0
# 56009                     NaN       2076.923077           NaN    NaN    NaN
# 13015                    31.0       4333.333333   4612.903226    NaN    1.0
# 1881                    130.0               NaN           NaN    NaN    4.0
# 93233                    41.0       1695.552791  31707.317073    NaN    NaN
# 48103                    55.0       1427.272727   1427.272727    NaN    3.0
# 109178                   43.0               NaN           NaN    NaN    NaN
# 5758                    120.0               NaN    516.666667    NaN    4.0
# 21696                   280.0               NaN           NaN    NaN    5.0
# 109294                   49.0               NaN           NaN    NaN    NaN
# 98682                    45.0       3000.000000   3333.333333    NaN    NaN
# 12549                    80.0       1875.000000   2062.500000    NaN    NaN
# 51                      324.0       1091.269841   1697.530864    NaN    NaN
# 54907                     NaN       1581.818182           NaN    NaN    3.0
#
#         expenses                                      properati_url  \
# 114074       NaN  http://www.properati.com.ar/1c9ci_venta_casa_a...
# 54132        NaN  http://www.properati.com.ar/19mjj_venta_casa_t...
# 111726       NaN  http://www.properati.com.ar/1c63a_venta_depart...
# 120493       NaN  http://www.properati.com.ar/1ci0x_venta_casa_v...
# 42447        NaN  http://www.properati.com.ar/18wh6_venta_casa_v...
# 98376        NaN  http://www.properati.com.ar/1blg2_venta_depart...
# 19705        NaN  http://www.properati.com.ar/17ah5_venta_depart...
# 56009        NaN  http://www.properati.com.ar/19q12_venta_depart...
# 13015        NaN  http://www.properati.com.ar/16nw4_venta_depart...
# 1881         NaN  http://www.properati.com.ar/15jj5_venta_casa_c...
# 93233        NaN  http://www.properati.com.ar/1bdwo_venta_depart...
# 48103        NaN  http://www.properati.com.ar/199km_venta_ph_mar...
# 109178       NaN  http://www.properati.com.ar/1c1vt_venta_depart...
# 5758         NaN  http://www.properati.com.ar/15rnp_venta_casa_m...
# 21696        NaN  http://www.properati.com.ar/17g12_venta_casa_h...
# 109294       NaN  http://www.properati.com.ar/1c1zu_venta_depart...
# 98682        NaN  http://www.properati.com.ar/1blsw_venta_depart...
# 12549        NaN  http://www.properati.com.ar/16m7u_venta_ph_vil...
# 51           NaN  http://www.properati.com.ar/15bui_venta_casa_b...
# 54907        NaN  http://www.properati.com.ar/19nzq_venta_depart...
#
#                                               description  \
# 114074  Hermosa y sólida casa a la venta en barrio abi...
# 54132   ***FIN DE OBRA: DICIEMBRE 2016 | LOTE INTERNO ...
# 111726  Departamento con Quincho, Mar del Plata, Const...
# 120493  Excelente propiedad, ubicada en en centro del ...
# 42447   Villa Luganocasa en lote propio de 13 años de ...
# 98376   Vendo departamento de 1 dormitorio tipo Loft. ...
# 19705   Corredor Responsable: Raul Hector Merlo - CUCI...
# 56009   Venta de Departamento 2 AMBIENTES en Altos de ...
# 13015   Departamento monoambiente al contrafrente con ...
# 1881    CASA EN DOS PLANTAS PARA ENTREGAR LLAVE EN MAN...
# 93233   Gran departamento en venta de 1 Dormitorio - C...
# 48103   Ph de 3 ambientes primer piso por escalera a l...
# 109178  Te invitamos a conocer:Casa Carreras - Contará...
# 5758    Living comedor, cocina comedor diario, dormito...
# 21696   Venta de Casa 5 AMBIENTES en Zona Ward, Haedo ...
# 109294  CARACTERÍSTICAS Departamento al contra frente ...
# 98682               Amplio e impecable monoambiente al...
# 12549   CODIGO: 683-1268 ubicado en: ARGERICH 5746 2DO...
# 51      Se encuentra dentro del Distrito Tecnológico. ...
# 54907   3 ambientes externo en La PerlaBuen departamen...
#
#                                                     title  \
# 114074         CASA EN VENTA EN ACACIAS BLANCAS Maschwitz
# 54132        Bustamante Propiedades | San Rafael en Venta
# 111726                        Departamento - Constitucion
# 120493                                  Casa - San Isidro
# 42447   casa moderna con garage , jardin con piscina y...
# 98376                Vendo departamento en Nueva Córdoba.
# 19705   IMPONENTE  piso   5 AMBIENTES + Habitacion de ...
# 56009                               DEPARTAMENTO EN VENTA
# 13015   Cabrera. José A. al 3900, entre Gascón y Acuña...
# 1881                      U$D 189.000 - Casa en Venta -
# 93233                        Departamento - Nueva Cordoba
# 48103            PH a la calle en San José. Apto Crédito!
# 109178          ***Viví General Paz, 1 dor, a estrenar***
# 5758                  Chalet 4 amb, gge p/3 autos y patio
# 21696                                       CASA EN VENTA
# 109294                             Departamento en Centro
# 98682                            Departamento en Belgrano
# 12549   PH 5 AMB. 2 BAÑOS (PISO UNICO) 2DO. POR ESCALE...
# 51              Casa impecable refaccionada! 6 ambientes.
# 54907                Departamento 3 ambientes en La Perla
#
#                                           image_thumbnail
# 114074  https://thumbs4.properati.com/7/YAwcAEgxWAdwLm...
# 54132   https://thumbs4.properati.com/1/6I_7hGpRkkKIl8...
# 111726                                                NaN
# 120493  https://thumbs4.properati.com/3/yd_RvDnrkF-bvk...
# 42447   https://thumbs4.properati.com/2/EJyb2vQGBpH-Oo...
# 98376   https://thumbs4.properati.com/6/geCZ9NUiYIV5-t...
# 19705   https://thumbs4.properati.com/3/55RJnEeIQhLbbo...
# 56009   https://thumbs4.properati.com/5/0B5hV4SBK9jEGD...
# 13015   https://thumbs4.properati.com/7/3xxc2gkM89mfQJ...
# 1881    https://thumbs4.properati.com/2/eFDA5JhjGDkhUK...
# 93233   https://thumbs4.properati.com/1/WJ_W6CSYH5-nki...
# 48103   https://thumbs4.properati.com/5/aO4djvwICUg1eB...
# 109178  https://thumbs4.properati.com/7/SLws63AXf9OZ8W...
# 5758    https://thumbs4.properati.com/2/5cwbISU9sRotCe...
# 21696   https://thumbs4.properati.com/5/4H9J_m7fZKwBba...
# 109294  https://thumbs4.properati.com/6/0DmuprAg9C9Xl9...
# 98682   https://thumbs4.properati.com/5/OGqoaIaEKitJAd...
# 12549   https://thumbs4.properati.com/4/_NYItqasVRB4Ze...
# 51      https://thumbs4.properati.com/4/bcATdI9jz_52YM...
# 54907   https://thumbs4.properati.com/8/dp3_NPi7uZcWKH...
#
# [20 rows x 26 columns]

# %%
#Veo la info del df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121220 entries, 0 to 121219
# Data columns (total 23 columns):
# Tipo_Operacion        121220 non-null object
# Tipo_Propiedad        121220 non-null object
# Barrio                121197 non-null object
# Ubicacion_Completa    121220 non-null object
# Pais                  121220 non-null object
# Provincia             121220 non-null object
# GeoNames_ID           102503 non-null float64
# Latitud_Longitud      69670 non-null object
# Latitud               69670 non-null float64
# Longitud              69670 non-null float64
# Precio                100810 non-null float64
# currency              100809 non-null object
# Precio_ARS            100810 non-null float64
# Precio_Dolares        100810 non-null float64
# Metros_Totales        81892 non-null float64
# Metros_Cubiertos      101313 non-null float64
# Precio_m2             68617 non-null float64
# price_per_m2          87658 non-null float64
# Pisos                 7899 non-null float64
# Cantidad_Ambientes    47390 non-null float64
# Expensas              14262 non-null float64
# Descripcion           121218 non-null object
# Titulo                121220 non-null object
# dtypes: float64(13), object(10)
# memory usage: 21.3+ MB

# %% [markdown]
# ## Vemos que hay varias columnas con valores vacios
#
# En particular vemoas que casi el 20% de las observaciones no tienen precio.
#
# Por otro lado, vemos que, tambien alrededor del 20% de las observaciones no cuentan con el campo Superficie Cubierta en m2 y casi un 35% no cuenta con el campo Superficie Total en m2

# %%
# Con el metodo describe podemos ver algunos estadisticos de cada columna
df.describe()

# %% [markdown]
# Esto nos puede dar un insight de como completar los valores faltantes de las variables mas relevantes

# %%
# Analizo las columnas para renombrar
df.columns
# Out:
# Index(['Tipo_Operacion', 'Tipo_Propiedad', 'Barrio', 'Ubicacion_Completa',
#        'Pais', 'Provincia', 'GeoNames_ID', 'Latitud_Longitud', 'Latitud',
#        'Longitud', 'Precio', 'currency', 'Precio_ARS', 'Precio_Dolares',
#        'Metros_Totales', 'Metros_Cubiertos', 'Precio_m2', 'price_per_m2',
#        'Pisos', 'Cantidad_Ambientes', 'Expensas', 'Descripcion', 'Titulo'],
#       dtype='object')

# %%
#Primero arreglo las irregularidades en las columnas
#Elimino las columnas que no aportan informacion descriptiva al df 

df = df.drop(['Unnamed: 0','image_thumbnail', 'properati_url'], axis=1)

#Renombro las columnas restantes para trabajar mas comodamente

df.rename(columns={ 'operation': 'Tipo_Operacion',
                    'property_type': 'Tipo_Propiedad',
                    'place_name': 'Barrio',
                    'place_with_parent_names': 'Ubicacion_Completa',
                    'country_name': 'Pais',
                    'state_name': 'Provincia',
                    'geonames_id': 'GeoNames_ID',
                    'lat-lon': 'Latitud_Longitud',
                    'lat': 'Latitud',
                    'lon': 'Longitud',
                    'price': 'Precio',
                    'Currency': 'Moneda',
                    'price_aprox_local_currency': 'Precio_ARS',
                    'price_aprox_usd': 'Precio_Dolares',
                    'surface_total_in_m2': 'Metros_Totales',
                    'surface_covered_in_m2': 'Metros_Cubiertos',
                    'price_usd_per_m2': 'Precio_m2',
                    'floor': 'Pisos',
                    'rooms': 'Cantidad_Ambientes',
                    'expenses': 'Expensas',
                    'description': 'Descripcion',
                    'title': 'Titulo'}, inplace=True)

# %%
df.head()
# Out:
#   Tipo_Operacion Tipo_Propiedad     Barrio  \
# 0           sell             PH  Mataderos
# 1           sell      apartment   La Plata
# 2           sell      apartment  Mataderos
# 3           sell             PH    Liniers
# 4           sell      apartment     Centro
#
#                                   Ubicacion_Completa       Pais  \
# 0              |Argentina|Capital Federal|Mataderos|  Argentina
# 1        |Argentina|Bs.As. G.B.A. Zona Sur|La Plata|  Argentina
# 2              |Argentina|Capital Federal|Mataderos|  Argentina
# 3                |Argentina|Capital Federal|Liniers|  Argentina
# 4  |Argentina|Buenos Aires Costa Atlántica|Mar de...  Argentina
#
#                       Provincia  GeoNames_ID         Latitud_Longitud  \
# 0               Capital Federal    3430787.0  -34.6618237,-58.5088387
# 1        Bs.As. G.B.A. Zona Sur    3432039.0  -34.9038831,-57.9643295
# 2               Capital Federal    3430787.0  -34.6522615,-58.5229825
# 3               Capital Federal    3431333.0  -34.6477969,-58.5164244
# 4  Buenos Aires Costa Atlántica    3435548.0  -38.0026256,-57.5494468
#
#      Latitud   Longitud                        ...                          \
# 0 -34.661824 -58.508839                        ...
# 1 -34.903883 -57.964330                        ...
# 2 -34.652262 -58.522982                        ...
# 3 -34.647797 -58.516424                        ...
# 4 -38.002626 -57.549447                        ...
#
#    Precio_Dolares Metros_Totales  Metros_Cubiertos    Precio_m2  price_per_m2  \
# 0         62000.0           55.0              40.0  1127.272727   1550.000000
# 1        150000.0            NaN               NaN          NaN           NaN
# 2         72000.0           55.0              55.0  1309.090909   1309.090909
# 3         95000.0            NaN               NaN          NaN           NaN
# 4         64000.0           35.0              35.0  1828.571429   1828.571429
#
#    Pisos  Cantidad_Ambientes  Expensas  \
# 0    NaN                 NaN       NaN
# 1    NaN                 NaN       NaN
# 2    NaN                 NaN       NaN
# 3    NaN                 NaN       NaN
# 4    NaN                 NaN       NaN
#
#                                          Descripcion  \
# 0  2 AMBIENTES TIPO CASA PLANTA BAJA POR PASILLO,...
# 1  Venta de departamento en décimo piso al frente...
# 2  2 AMBIENTES 3ER PISO LATERAL LIVING COMEDOR AM...
# 3  PH 3 ambientes con patio. Hay 3 deptos en lote...
# 4  DEPARTAMENTO CON FANTÁSTICA ILUMINACIÓN NATURA...
#
#                                               Titulo
# 0                 2 AMB TIPO CASA SIN EXPENSAS EN PB
# 1  VENTA Depto 2 dorm. a estrenar 7 e/ 36 y 37   ...
# 2           2 AMB 3ER PISO CON ASCENSOR APTO CREDITO
# 3                       PH 3 amb. cfte. reciclado
# 4  DEPTO 2 AMB AL CONTRAFRENTE ZONA CENTRO/PLAZA ...
#
# [5 rows x 23 columns]

# %%
# Hago un value_count de las columnas que me interesan ver
for c in ['Tipo_Propiedad', 'Provincia']:
        print ('-----{}-----'.format(c))
        print (df[c].value_counts())
        print('')
# Out:
# -----Tipo_Propiedad-----
# apartment    71065
# house        40268
# PH            5751
# store         4136
# Name: Tipo_Propiedad, dtype: int64
#
# -----Provincia-----
# Capital Federal                 32316
# Bs.As. G.B.A. Zona Norte        25560
# Bs.As. G.B.A. Zona Sur          13952
# Córdoba                         12069
# Santa Fe                        10172
# Buenos Aires Costa Atlántica    10006
# Bs.As. G.B.A. Zona Oeste         9322
# Buenos Aires Interior            2291
# Río Negro                         808
# Neuquén                           733
# Mendoza                           681
# Tucumán                           674
# Corrientes                        583
# Misiones                          464
# Entre Ríos                        369
# Salta                             278
# Chubut                            259
# San Luis                          252
# La Pampa                          157
# Formosa                            65
# Chaco                              57
# San Juan                           40
# Tierra Del Fuego                   31
# Catamarca                          27
# Jujuy                              26
# Santa Cruz                         20
# Santiago Del Estero                 4
# La Rioja                            4
# Name: Provincia, dtype: int64
